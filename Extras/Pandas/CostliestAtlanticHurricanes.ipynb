# %% [markdown]
# # Overview
# Hurricanes can be very damaging in terms of life and cost as we have seen during the year 2017, when hurricanes like Harvey, Irma and Maria caused pandemonium in the Atlantic Basin. We have compiled from Wikipedia a list of the costliest hurricanes in the Atlantic. This data can give us insights on which have been the most costly hurricanes, the busiest seasons, and the areas that have been affected the most.

# %% [markdown]
# # Data & Setup
# The data has been collected from https://en.wikipedia.org/wiki/List_of_costliest_Atlantic_hurricanes. The data from 2017 has not been published yet, so it's not included in this dataset

# %%
import pandas as pd
import numpy as np

df1 = pd.read_html('https://en.wikipedia.org/wiki/List_of_costliest_Atlantic_hurricanes')
df = df1[0].drop(df1[0].index[0]).drop(5, axis=1)
df.columns = ['Name','Cost in Billions','Season','Classification','Areas Affected']
df['Classification']=df['Classification'].apply(lambda x: str(x)[3:]).apply(lambda x: x.strip()).replace('\xa0',' ',regex=True)
df['Cost in Billions']=df['Cost in Billions'].apply(lambda x: str(x)[1:]).apply(pd.to_numeric)
df
# Out:
#         Name  Cost in Billions Season        Classification  \
# 1    Katrina           108.000   2005  Category 5 hurricane
# 2      Sandy            75.000   2012  Category 3 hurricane
# 3        Ike            37.500   2008  Category 4 hurricane
# 4      Wilma            29.400   2005  Category 5 hurricane
# 5     Andrew            26.500   1992  Category 5 hurricane
# 6       Ivan            23.300   2004  Category 5 hurricane
# 7      Irene            16.600   2011  Category 3 hurricane
# 8    Charley            16.300   2004  Category 4 hurricane
# 9    Matthew            15.090   2016  Category 5 hurricane
# 10      Rita            12.000   2005  Category 5 hurricane
# 11      Hugo            10.000   1989  Category 5 hurricane
# 12   Frances             9.800   2004  Category 4 hurricane
# 13   Georges             9.720   1998  Category 4 hurricane
# 14   Allison             9.000   2001        Tropical storm
# 15    Jeanne             7.660   2004  Category 3 hurricane
# 16   Gilbert             7.100   1988  Category 5 hurricane
# 17     Floyd             6.900   1999  Category 4 hurricane
# 18    Gustav             6.610   2008  Category 4 hurricane
# 19     Mitch             6.200   1998  Category 5 hurricane
# 20    Isabel             5.370   2003  Category 5 hurricane
# 21      Opal             5.100   1995  Category 4 hurricane
# 22      Stan             3.960   2005  Category 1 hurricane
# 23      Karl             3.900   2010  Category 3 hurricane
# 24    Dennis             3.710   2005  Category 4 hurricane
# 25      Fran             3.200   1996  Category 3 hurricane
# 26      Luis             3.000   1995  Category 4 hurricane
# 27   Marilyn             2.500   1995  Category 3 hurricane
# 28       Lee             2.500   2011        Tropical storm
# 29     Isaac             2.390   2012  Category 1 hurricane
# 30  Frederic             2.300   1979  Category 4 hurricane
# 31     Agnes             2.100   1972  Category 1 hurricane
# 32      Joan             2.000   1988  Category 4 hurricane
# 33  Michelle             2.000   2001  Category 4 hurricane
# 34      Alex             1.885   2010  Category 2 hurricane
# 35      Fifi             1.800   1974  Category 2 hurricane
# 36      Dean             1.780   2007  Category 5 hurricane
# 37    Alicia             1.700   1983  Category 3 hurricane
# 38     David             1.540   1979  Category 5 hurricane
# 39      Juan             1.500   1985  Category 1 hurricane
# 40       Bob             1.500   1991  Category 3 hurricane
# 41   Roxanne             1.500   1995  Category 3 hurricane
# 42    Ingrid             1.500   2013  Category 1 hurricane
# 43     Betsy             1.450   1965  Category 4 hurricane
# 44   Camille             1.420   1969  Category 5 hurricane
# 45     Dolly             1.350   2008  Category 2 hurricane
# 46     Elena             1.300   1985  Category 3 hurricane
# 47   Isidore             1.300   2002  Category 3 hurricane
# 48     Allen             1.240   1980  Category 5 hurricane
# 49     Emily             1.014   2005  Category 5 hurricane
# 50    Beulah             1.000   1967  Category 5 hurricane
# 51   Alberto             1.000   1994        Tropical storm
#
#                                        Areas Affected
# 1   The Bahamas Florida United States Gulf Coast O...
# 2   The Caribbean United States East Coast Eastern...
# 3   Greater Antilles Texas Louisiana Midwestern Un...
# 4            Greater Antilles Central America Florida
# 5        The Bahamas Florida United States Gulf Coast
# 6    The Caribbean Venezuela United States Gulf Coast
# 7   The Caribbean United States East Coast Eastern...
# 8   Jamaica Cayman Islands Cuba Florida The Carolinas
# 9   Colombia Venezuela The Caribbean United States...
# 10                      Cuba United States Gulf Coast
# 11             The Caribbean United States East Coast
# 12        The Caribbean Eastern United States Ontario
# 13             The Caribbean United States Gulf Coast
# 14             Texas Louisiana Southern United States
# 15                The Caribbean Eastern United States
# 16        Venezuela Central America Hispaniola Mexico
# 17  The Bahamas Eastern United States Atlantic Canada
# 18   Hispaniola Jamaica Cuba United States Gulf Coast
# 19    Central America Yucatán Peninsula South Florida
# 20  Greater Antilles The Bahamas Eastern United St...
# 21  Guatemala Yucatán Peninsula Eastern United States
# 22                             Mexico Central America
# 23                             Mexico Central America
# 24        Greater Antilles Southeastern United States
# 25                      Eastern United States Ontario
# 26                Leeward Islands Puerto Rico Bermuda
# 27                              The Caribbean Bermuda
# 28                           United States East Coast
# 29                The Caribbean Eastern United States
# 30           The Caribbean Southeastern United States
# 31                  Mexico Cuba Eastern United States
# 32  Lesser Antilles Colombia Venezuela Central Ame...
# 33           Central America Jamaica Cuba The Bahamas
# 34             Central America Greater Antilles Texas
# 35                     Jamaica Central America Mexico
# 36                      The Caribbean Central America
# 37                               East Texas Louisiana
# 38             The Caribbean United States East Coast
# 39                           United States Gulf Coast
# 40                    United States East Coast Canada
# 41                                             Mexico
# 42                                             Mexico
# 43           The Caribbean Southeastern United States
# 44                      Cuba United States Gulf Coast
# 45   Cayman Islands Mexico Southwestern United States
# 46                      Cuba United States Gulf Coast
# 47                   Cuba Yucatán Peninsula Louisiana
# 48  The Caribbean Yucatán Peninsula Mexico South T...
# 49  Guyana Colombia The Caribbean Honduras Belize ...
# 50                         The Caribbean Mexico Texas
# 51                         Southeastern United States

# %%
# list the 10 most costly hurricanes and their season
# it should return a dataframe with two columns: the name of the hurricane and the season
def question1():
    data = df
    return "Answer" # put your answer here

# %%
# find the four seasons with the most hurricanes on this list: 
# return a dataset of size 4 with an index of 
# season, and a value of number of hurricanes for that season
# ordered from most hurricanes to least hurricanes:
# e.g
# 2005  6
# 2012  2
# ... 
def question2():
    data = df
    return "Answer" # put your answer here

# %%
# compare the cost of the damage caused by the hurricanes for Cuba, 
# Mexico and United States.
# return a tuple with the three countries in order from more cost sustained
# by hurricane damage to less cost sustained
# e.g ('United States','Mexico','Cuba')
# you can manually build the tuple based on the results
# tip: you can use str.contains to look for that country string in the 'Areas Affected' column
def question3():
    data = df
    return "Answer" # put your answer here

# %%
#List the four seasons which were most costly along with its associated cost
#put your results in a series where the index is the season and the value is the cost
# tip: you will need to use a groupby on the Season and then add the cost
def question4():
    data = df
    return "Answer" # put your answer here

# %%
# How much more costly were hurricanes of category 5 than hurricanes of category 4
# you result should be a single number representing the difference in billions
# tip: you'll need to use a groupby on the Classification column
def question5():
    data = df
    return "Answer" # put your answer here
