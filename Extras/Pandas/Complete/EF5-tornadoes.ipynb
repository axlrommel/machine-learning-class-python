# %% [markdown]
# # Overview
# Tornadoes can be very deadly and destructive. In order to understand how strong tornadoes can get, scientists commonly use the Fujita scale, which rates tornadoes by damage caused. On one side of the Fujita scale are tornadoes of category EF0, which may damage trees but will not cause substantial damage to homes and buildings. On the other side of the scale, tornadoes of category EF5 are the strongest type of tornadoes, they are very damaging to structures and are often the most deadly. Most of the EF5 tornadoes occur in the Midwest and the Southern United States. In this exercise we want to look at where exactly the strongest tornadoes occur, what months they are more likely to occur and how many deaths they are responsible for.

# %% [markdown]
# # Data & Setup
# #The source for the data is the wikipedia page on the list of F5 and EF5 tornadoes from 1950 to 2016

# %%
import pandas as pd
import numpy as np
proxy='https://proxy.mentoracademy.org/getContentFromWikiUrl/'
df1 = pd.read_html('https://en.wikipedia.org/wiki/List_of_F5_and_EF5_tornadoes')
#read 3rd and 4th table, drop first row and last column on each
dfa = df1[2].drop(df1[2].index[0]).drop([4], axis=1)
dfb = df1[3].drop(df1[3].index[0]).drop([4], axis=1)

#concatenate 3rd table (1950-1999) and 4th table (2000 - present)
df = pd.concat([dfa,dfb])

df.columns = ['Month-Day'  ,'Year'  ,'Location','Deaths']
df['Year']=df['Year'].apply(lambda x: str(x)[-4:])
df['Month-Day'] = df['Month-Day'].apply(lambda x: str(x)[-len(x)+x.index("!")+1:])
df['Deaths'] = df['Deaths'].apply(lambda x: str(x)[-len(x)+x.index("♠")+1:]).apply(pd.to_numeric)
df
# Out:
#       Month-Day  Year                                 Location  Deaths
# 1        May 18  1951                             Olney, Texas       2
# 2      March 21  1952   Byhalia, Mississippi–Moscow, Tennessee      17
# 3        May 22  1952       Douglas–Leavenworth County, Kansas       0
# 4        May 11  1953                              Waco, Texas     114
# 5        May 29  1953                  Fort Rice, North Dakota       2
# 6        June 8  1953                          Flint, Michigan     116
# 7        June 8  1953                             Cygnet, Ohio      18
# 8        June 9  1953                 Worcester, Massachusetts      94
# 9       June 27  1953                              Adair, Iowa       1
# 10   December 5  1953                   Vicksburg, Mississippi      38
# 11        May 1  1954   Crowell–Vernon, Texas–Snyder, Oklahoma       0
# 12       May 25  1955                      Blackwell, Oklahoma      20
# 13       May 25  1955                            Udall, Kansas      80
# 14       July 2  1955                    Walcott, North Dakota       2
# 15      April 3  1956       Hudsonville–Grand Rapids, Michigan      18
# 16       May 20  1957                 Ruskin Heights, Missouri      44
# 17       May 21  1957                        Fremont, Missouri       7
# 18      June 16  1957   Robecco Pavese–Valle Scuropasso, Italy       7
# 19      June 20  1957                      Fargo, North Dakota      10
# 20  December 18  1957                       Sunfield, Illinois       1
# 21       June 4  1958              Menomonie–Colfax, Wisconsin      21
# 22      June 10  1958                        El Dorado, Kansas      15
# 23        May 5  1960                         Prague, Oklahoma       5
# 24       May 19  1960                           Wamego, Kansas       0
# 25       May 20  1960                        Niechobrz, Poland       4
# 26       May 30  1961           Custer–Valley County, Nebraska       0
# 27      April 3  1964                     Wichita Falls, Texas       7
# 28     April 12  1964                    Near Lawrence, Kansas       0
# 29        May 5  1964                       Bradshaw, Nebraska       4
# 30     April 11  1965                          Midway, Indiana      14
# ..          ...   ...                                      ...     ...
# 72       June 1  1990                            Girvin, Texas       0
# 73    August 28  1990                     Plainfield, Illinois      29
# 74     April 26  1991                          Andover, Kansas      17
# 75     April 26  1991                       Red Rock, Oklahoma       0
# 76      June 16  1992                      Chandler, Minnesota       1
# 77       June 8  1995                       Kellerville, Texas       0
# 78      July 18  1996                      Oakfield, Wisconsin       0
# 79       May 27  1997                           Jarrell, Texas      27
# 80      April 8  1998        Oak Grove–Pleasant Grove, Alabama      32
# 81     April 16  1998                  Wayne County, Tennessee       3
# 82     April 16  1998               Lawrence County, Tennessee       0
# 83        May 3  1999             Bridge Creek–Moore, Oklahoma      36
# 84       May 11  1999                      Loyal Valley, Texas       1
# 1         May 4  2003                  Girard–Franklin, Kansas       3
# 2         May 4  2007                       Greensburg, Kansas      11
# 3       June 22  2007                           Elie, Manitoba       0
# 4        May 25  2008           Parkersburg–New Hartford, Iowa       9
# 5      April 27  2011        Philadelphia–Preston, Mississippi       3
# 6      April 27  2011                  Smithville, Mississippi      23
# 7      April 27  2011        Hackleburg–Phil Campbell, Alabama      72
# 8      April 27  2011           Tuscaloosa–Birmingham, Alabama      64
# 9      April 27  2011             Rainsville–Sylvania, Alabama      25
# 10       May 22  2011                         Joplin, Missouri     158
# 11       May 24  2011               El Reno–Piedmont, Oklahoma       9
# 12       May 24  2011  Chickasha–Blanchard–Newcastle, Oklahoma       1
# 13       May 24  2011             Washington–Goldsby, Oklahoma       0
# 14       May 20  2013                          Moore, Oklahoma      24
# 15       May 31  2013                        El Reno, Oklahoma       8
# 16     April 27  2014                        Vilonia, Arkansas      16
# 17      April 9  2015                       Rochelle, Illinois       2
#
# [101 rows x 4 columns]

# %% [markdown]
# # Skills & Concepts
# * python-lambda
# * python-numpy
# * python-pandas-Series
# * python-pandas-DataFrame

# %%
def getDF():
    return df

# %%
# extract the month from the 'Month-Day' column and put it in column called 'Month'
#drop the 'Month-Day' column
def question1():

    return "answer"

# %%
# use a lambda function to extract the Month from the 'Month Day' column
def solution1():
    df = getDF()
    df['Month'] = df['Month-Day'].apply(lambda x: str(x)[:-len(x)+x.index(" ")+1]).apply(lambda x: x.strip())
    df = df.drop('Month-Day', 1)
    return df

solution1()
# Out:
#     Year                                 Location  Deaths     Month
# 1   1951                             Olney, Texas       2       May
# 2   1952   Byhalia, Mississippi–Moscow, Tennessee      17     March
# 3   1952       Douglas–Leavenworth County, Kansas       0       May
# 4   1953                              Waco, Texas     114       May
# 5   1953                  Fort Rice, North Dakota       2       May
# 6   1953                          Flint, Michigan     116      June
# 7   1953                             Cygnet, Ohio      18      June
# 8   1953                 Worcester, Massachusetts      94      June
# 9   1953                              Adair, Iowa       1      June
# 10  1953                   Vicksburg, Mississippi      38  December
# 11  1954   Crowell–Vernon, Texas–Snyder, Oklahoma       0       May
# 12  1955                      Blackwell, Oklahoma      20       May
# 13  1955                            Udall, Kansas      80       May
# 14  1955                    Walcott, North Dakota       2      July
# 15  1956       Hudsonville–Grand Rapids, Michigan      18     April
# 16  1957                 Ruskin Heights, Missouri      44       May
# 17  1957                        Fremont, Missouri       7       May
# 18  1957   Robecco Pavese–Valle Scuropasso, Italy       7      June
# 19  1957                      Fargo, North Dakota      10      June
# 20  1957                       Sunfield, Illinois       1  December
# 21  1958              Menomonie–Colfax, Wisconsin      21      June
# 22  1958                        El Dorado, Kansas      15      June
# 23  1960                         Prague, Oklahoma       5       May
# 24  1960                           Wamego, Kansas       0       May
# 25  1960                        Niechobrz, Poland       4       May
# 26  1961           Custer–Valley County, Nebraska       0       May
# 27  1964                     Wichita Falls, Texas       7     April
# 28  1964                    Near Lawrence, Kansas       0     April
# 29  1964                       Bradshaw, Nebraska       4       May
# 30  1965                          Midway, Indiana      14     April
# ..   ...                                      ...     ...       ...
# 72  1990                            Girvin, Texas       0      June
# 73  1990                     Plainfield, Illinois      29    August
# 74  1991                          Andover, Kansas      17     April
# 75  1991                       Red Rock, Oklahoma       0     April
# 76  1992                      Chandler, Minnesota       1      June
# 77  1995                       Kellerville, Texas       0      June
# 78  1996                      Oakfield, Wisconsin       0      July
# 79  1997                           Jarrell, Texas      27       May
# 80  1998        Oak Grove–Pleasant Grove, Alabama      32     April
# 81  1998                  Wayne County, Tennessee       3     April
# 82  1998               Lawrence County, Tennessee       0     April
# 83  1999             Bridge Creek–Moore, Oklahoma      36       May
# 84  1999                      Loyal Valley, Texas       1       May
# 1   2003                  Girard–Franklin, Kansas       3       May
# 2   2007                       Greensburg, Kansas      11       May
# 3   2007                           Elie, Manitoba       0      June
# 4   2008           Parkersburg–New Hartford, Iowa       9       May
# 5   2011        Philadelphia–Preston, Mississippi       3     April
# 6   2011                  Smithville, Mississippi      23     April
# 7   2011        Hackleburg–Phil Campbell, Alabama      72     April
# 8   2011           Tuscaloosa–Birmingham, Alabama      64     April
# 9   2011             Rainsville–Sylvania, Alabama      25     April
# 10  2011                         Joplin, Missouri     158       May
# 11  2011               El Reno–Piedmont, Oklahoma       9       May
# 12  2011  Chickasha–Blanchard–Newcastle, Oklahoma       1       May
# 13  2011             Washington–Goldsby, Oklahoma       0       May
# 14  2013                          Moore, Oklahoma      24       May
# 15  2013                        El Reno, Oklahoma       8       May
# 16  2014                        Vilonia, Arkansas      16     April
# 17  2015                       Rochelle, Illinois       2     April
#
# [101 rows x 4 columns]

# %%
#create a separate column where you just list the state/country, use the last comma in 
# the Location field to separate it
#drop the Location column
def question2():

    return "answer"

# %%
def solution2():
    df = solution1()
    df['Loc'] = df['Location'].apply(lambda x: str(x)[-len(x)+x.rfind(",")+1:]).apply(lambda x: x.strip())
    df = df.drop('Location',1)
    return df

solution2()
# Out:
#     Year  Deaths     Month            Loc
# 1   1951       2       May          Texas
# 2   1952      17     March      Tennessee
# 3   1952       0       May         Kansas
# 4   1953     114       May          Texas
# 5   1953       2       May   North Dakota
# 6   1953     116      June       Michigan
# 7   1953      18      June           Ohio
# 8   1953      94      June  Massachusetts
# 9   1953       1      June           Iowa
# 10  1953      38  December    Mississippi
# 11  1954       0       May       Oklahoma
# 12  1955      20       May       Oklahoma
# 13  1955      80       May         Kansas
# 14  1955       2      July   North Dakota
# 15  1956      18     April       Michigan
# 16  1957      44       May       Missouri
# 17  1957       7       May       Missouri
# 18  1957       7      June          Italy
# 19  1957      10      June   North Dakota
# 20  1957       1  December       Illinois
# 21  1958      21      June      Wisconsin
# 22  1958      15      June         Kansas
# 23  1960       5       May       Oklahoma
# 24  1960       0       May         Kansas
# 25  1960       4       May         Poland
# 26  1961       0       May       Nebraska
# 27  1964       7     April          Texas
# 28  1964       0     April         Kansas
# 29  1964       4       May       Nebraska
# 30  1965      14     April        Indiana
# ..   ...     ...       ...            ...
# 72  1990       0      June          Texas
# 73  1990      29    August       Illinois
# 74  1991      17     April         Kansas
# 75  1991       0     April       Oklahoma
# 76  1992       1      June      Minnesota
# 77  1995       0      June          Texas
# 78  1996       0      July      Wisconsin
# 79  1997      27       May          Texas
# 80  1998      32     April        Alabama
# 81  1998       3     April      Tennessee
# 82  1998       0     April      Tennessee
# 83  1999      36       May       Oklahoma
# 84  1999       1       May          Texas
# 1   2003       3       May         Kansas
# 2   2007      11       May         Kansas
# 3   2007       0      June       Manitoba
# 4   2008       9       May           Iowa
# 5   2011       3     April    Mississippi
# 6   2011      23     April    Mississippi
# 7   2011      72     April        Alabama
# 8   2011      64     April        Alabama
# 9   2011      25     April        Alabama
# 10  2011     158       May       Missouri
# 11  2011       9       May       Oklahoma
# 12  2011       1       May       Oklahoma
# 13  2011       0       May       Oklahoma
# 14  2013      24       May       Oklahoma
# 15  2013       8       May       Oklahoma
# 16  2014      16     April       Arkansas
# 17  2015       2     April       Illinois
#
# [101 rows x 4 columns]

# %%
# using 'isin' create two dataframes, one with the data that have a loc in one of the
# states in the following list, the other without
def question3():

    states = ['Wisconsin', 'Texas', 'Oklahoma', 'Minnesota', 'Alabama', 'Tennessee', 'Kansas', 
              'Pennsylvania', 'South Dakota', 'Iowa', 'Ohio', 'Kentucky', 'Indiana', 'Nebraska', 'Illinois', 
              'North Dakota', 'Missouri', 'Michigan', 'Mississippi', 'Massachusetts','Louisiana']
    return "answer"

# %%
def solution3():
    df = solution2()
    states = ['Wisconsin', 'Texas', 'Oklahoma', 'Minnesota', 'Alabama', 'Tennessee', 'Kansas', 
              'Pennsylvania', 'South Dakota', 'Iowa', 'Ohio', 'Kentucky', 'Indiana', 'Nebraska', 'Illinois', 
              'North Dakota', 'Missouri', 'Michigan', 'Mississippi', 'Massachusetts','Louisiana']
    df_us = df.loc[df['Loc'].isin(states)]
    df_non_us = df.loc[~df['Loc'].isin(states)]
    return (df_us, df_non_us)

solution3()
# Out:
# (    Year  Deaths     Month            Loc
#  1   1951       2       May          Texas
#  2   1952      17     March      Tennessee
#  3   1952       0       May         Kansas
#  4   1953     114       May          Texas
#  5   1953       2       May   North Dakota
#  6   1953     116      June       Michigan
#  7   1953      18      June           Ohio
#  8   1953      94      June  Massachusetts
#  9   1953       1      June           Iowa
#  10  1953      38  December    Mississippi
#  11  1954       0       May       Oklahoma
#  12  1955      20       May       Oklahoma
#  13  1955      80       May         Kansas
#  14  1955       2      July   North Dakota
#  15  1956      18     April       Michigan
#  16  1957      44       May       Missouri
#  17  1957       7       May       Missouri
#  19  1957      10      June   North Dakota
#  20  1957       1  December       Illinois
#  21  1958      21      June      Wisconsin
#  22  1958      15      June         Kansas
#  23  1960       5       May       Oklahoma
#  24  1960       0       May         Kansas
#  26  1961       0       May       Nebraska
#  27  1964       7     April          Texas
#  28  1964       0     April         Kansas
#  29  1964       4       May       Nebraska
#  30  1965      14     April        Indiana
#  31  1965       5     April        Indiana
#  32  1965      36     April        Indiana
#  ..   ...     ...       ...            ...
#  70  1990       1     March         Kansas
#  71  1990       1     March         Kansas
#  72  1990       0      June          Texas
#  73  1990      29    August       Illinois
#  74  1991      17     April         Kansas
#  75  1991       0     April       Oklahoma
#  76  1992       1      June      Minnesota
#  77  1995       0      June          Texas
#  78  1996       0      July      Wisconsin
#  79  1997      27       May          Texas
#  80  1998      32     April        Alabama
#  81  1998       3     April      Tennessee
#  82  1998       0     April      Tennessee
#  83  1999      36       May       Oklahoma
#  84  1999       1       May          Texas
#  1   2003       3       May         Kansas
#  2   2007      11       May         Kansas
#  4   2008       9       May           Iowa
#  5   2011       3     April    Mississippi
#  6   2011      23     April    Mississippi
#  7   2011      72     April        Alabama
#  8   2011      64     April        Alabama
#  9   2011      25     April        Alabama
#  10  2011     158       May       Missouri
#  11  2011       9       May       Oklahoma
#  12  2011       1       May       Oklahoma
#  13  2011       0       May       Oklahoma
#  14  2013      24       May       Oklahoma
#  15  2013       8       May       Oklahoma
#  17  2015       2     April       Illinois
#
#  [91 rows x 4 columns],     Year  Deaths    Month              Loc
#  18  1957       7     June            Italy
#  25  1960       4      May           Poland
#  41  1967       6     June           France
#  47  1970       0  January  New South Wales
#  52  1973      54  January        Argentina
#  66  1984      92     June     Soviet Union
#  67  1984       0     June     Soviet Union
#  69  1987      27     July          Alberta
#  3   2007       0     June         Manitoba
#  16  2014      16    April         Arkansas)

# %%
#list the top 5 years when F5 caused the most deaths in the US
def question4():
    df_us, df_non_us = question3()
    return "answer"

# %%
def solution4():
    df_us, df_non_us = solution3()
    return df_us.groupby('Year')['Deaths'].sum().sort_values(ascending=False).head(5)

solution4()
# Out:
# Year
# 1953    383
# 2011    355
# 1974    150
# 1965    123
# 1955    102
# Name: Deaths, dtype: int64

# %%
#list the 5 months that F5 caused the most deaths in the US, along with the number of deaths
def question5():
    df_us, df_non_us = question3()
    return "answer"

# %%
def solution5():
    df_us, df_non_us = solution3()
    return df_us.groupby('Month')['Deaths'].sum().sort_values(ascending=False).head(5)

solution5()
# Out:
# Month
# May         631
# April       572
# June        310
# March        78
# February     47
# Name: Deaths, dtype: int64

# %%
# what three months are F5 tornadoes more common in the US, return a Series with month as the index, 
# and the value is the number of occurrences
def question6():
    df_us, df_non_us = question3()
    return "answer"

# %%
def solution6():
    df_us, df_non_us = solution3()
    return df_us['Month'].value_counts().head(3)

solution6()
# Out:
# April    33
# May      32
# June     14
# Name: Month, dtype: int64

# %%
#what month are F5 tornadoes more common outside the US
def question7():
    df_us, df_non_us = question3()
    return "answer"

# %%
def solution7():
    df_us, df_non_us = solution3()
    return df_non_us['Month'].value_counts().head(1)

solution7()
# Out:
# June    5
# Name: Month, dtype: int64

# %%
# list the five states that have seen the most deaths due to F5 tornadoes, including the number of deaths
def question8():
    df_us, df_non_us = question3()
    return "answer"

# %%
def solution8():
    df_us, df_non_us = solution3()
    return df_us.groupby('Loc')['Deaths'].sum().sort_values(ascending=False).head(5)

solution8()
# Out:
# Loc
# Alabama     293
# Missouri    209
# Texas       177
# Kansas      144
# Michigan    134
# Name: Deaths, dtype: int64

# %%
# what four states have seen the most F5 tornadoes. return a Series with the index as the State and the value as the
# number of tornadoes that the state has seen
def question9():
    df_us, df_non_us = question3()
    return "answer"

# %%
def solution9():
    df_us, df_non_us = solution3()
    return df_us['Loc'].value_counts().head(4)

solution9()
# Out:
# Oklahoma    12
# Kansas      11
# Texas       10
# Alabama      8
# Name: Loc, dtype: int64

# %%
# what country not in the US has seen the most deaths due to F5 tornadoes
def question10():
    df_us, df_non_us = question3()
    return "answer"

# %%
def solution10():
    df_us, df_non_us = solution3()
    return df_non_us['Loc'].value_counts().head(1)

solution10()
# Out:
# Soviet Union    2
# Name: Loc, dtype: int64

# %%
# List the top three years when the US had the most F5 tornadoes. Return a Series with the index as the year and the
# value as the number of tornadoes

def question11():
    df_us, df_non_us = question3()
    return "answer"

# %%
def solution11():
    df_us, df_non_us = solution3()
    return df_us['Year'].value_counts().head(3)

solution11()
# Out:
# 2011    9
# 1965    8
# 1953    7
# Name: Year, dtype: int64

# %%
#on average, how many people are killed by an F5 tornado in the US, return a formatted number with one decimal
# hint you can use "{:2.1f}".format(x)
def question12():
    df_us, df_non_us = question3()
    return "answer"

# %%
def solution12():
    df_us, df_non_us = solution3()
    return "{:2.1f}".format(df_us['Deaths'].mean())

solution12()
# Out:
# '18.8'
